# %%
from util import hello

hello("prem")

# %%
df = spark.read.format("csv").options(header="true").load("/Volumes/nonprod/landing/data/countries_dataset/countries_dataset/csv_data/countries_population/countries_population.csv")

df.display()

# %%
df.write.mode("overwrite").format("delta").saveAsTable("nonprod.landing.countries")

# %%
df_new = spark.read.table("nonprod.landing.countries")

df_new.filter("NAME='India'").display()

# %%
# %sql
select * from nonprod.landing.countries

# %%
spark.sql("""
          DESCRIBE HISTORY nonprod.landing.countries
          """).display()

# %%
from delta.tables import DeltaTable

dt = DeltaTable.forName(spark, "nonprod.landing.countries")

# %%
for i in range(20):
    dt.update(
    condition = f"COUNTRY_ID='{i}'",
    set = {
        'POPULATION': f'{i+109}'
    }
)

# %%
spark.read.table("nonprod.landing.countries").display()

# %%
# %sql
DESCRIBE DETAIL nonprod.landing.countries;

# %%
spark.sql("""
          DESCRIBE HISTORY nonprod.landing.countries
          """).display()

# %%
spark.read.format("delta").option("versionAsOf", 0).table("nonprod.landing.countries").filter("COUNTRY_ID='167'")\
    .display()

# %%
spark.read.option("versionAsOf", 1).table("nonprod.landing.countries").filter("COUNTRY_ID='167'")\
    .display()
